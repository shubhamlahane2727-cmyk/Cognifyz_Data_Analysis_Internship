# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Dataset (internship).csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
from collections import Counter

# %%
cuisine_counts = Counter(all_cuisines)
cuisine_counts.most_common(10)
# Out:
# [('North Indian', 3960),
#  ('Chinese', 2735),
#  ('Fast Food', 1986),
#  ('Mughlai', 995),
#  ('Italian', 764),
#  ('Bakery', 745),
#  ('Continental', 736),
#  ('Cafe', 703),
#  ('Desserts', 653),
#  ('South Indian', 636)]

# %%
top_3_cuisines = cuisine_counts.most_common(3)
total_restaurants = df.shape[0]

for cuisine, count in top_3_cuisines:
    print(f"{cuisine}: {(count/total_restaurants)*100:.2f}%")
# Out:
# North Indian: 41.46%
# Chinese: 28.64%
# Fast Food: 20.79%

# %%
cuisines = [c[0] for c in top_3_cuisines]
counts = [c[1] for c in top_3_cuisines]

plt.bar(cuisines, counts)
plt.title("Top 3 Most Common Cuisines")
plt.xlabel("Cuisine")
plt.ylabel("Number of Restaurants")
plt.show()

# %% [markdown]
# Level 1 – Task 1: Top Cuisines
#
# In this task, I analyzed the ‘Cuisines’ column from the dataset to identify the most common cuisines served by restaurants. Since a restaurant can offer multiple cuisines, the values were split and flattened into a single list. Using frequency analysis, the top three cuisines were identified. The percentage of restaurants serving each cuisine was calculated based on the total number of restaurants in the dataset.
